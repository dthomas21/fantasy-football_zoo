# %%
# !pip install selenium
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/80/d6/4294f0b4bce4de0abf13e17190289f9d0613b0a44e5dd6a7f5ca98459853/selenium-3.141.0-py2.py3-none-any.whl
# ...
# You are using pip version 19.0.3, however version 19.2.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import time
from selenium import webdriver
import requests
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')  # Optional argument, if not specified will search path.
# or, fill in your ANACONDA_INSTALL_DIR and try this:
# driver = webdriver.Chrome('ANACONDA_INSTALL_DIR/chromedriver-Darwin')

driver.get('https://www.easports.com/madden-nfl/player-ratings')

# here is where some useful work would typically happen
# for i in range(10):
#     time.sleep(10)
#     driver.execute_script("window.scrollTo(0, 100000);")
#     print('scrolled', i)

time.sleep(10)


input("Press Enter to quit")
driver.quit() # close browser
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-2-b4dcc2d0fdaf> in <module>
#       3 # driver = webdriver.Chrome('ANACONDA_INSTALL_DIR/chromedriver-Darwin')
#       4
# ----> 5 driver.get('https://www.easports.com/madden-nfl/player-ratings')
#       6
#       7 # here is where some useful work would typically happen
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in get(self, url)
#     331         Loads a web page in the current browser session.
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#     335     @property
#
# ~/miniconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
driver = webdriver.Chrome('/usr/local/bin/chromedriver')  # Optional argument, if not specified will search path.
driver.get('http://www.google.com')

search_box = driver.find_element_by_name('q')
search_box.send_keys('USF data science')
search_box.submit()

input("Press Enter to quit")
driver.quit() # close browser
# Out:
# Press Enter to quit

# %%
response = requests.get("https://news.ycombinator.com/newest")
soup = BeautifulSoup(response.text, "html.parser")

# for link in soup.find_all(class_="storylink"):
#for link in soup.find_all("a", {"class":"storylink"}):
for link in soup.find_all("a"):
    if 'class' in link.attrs:
        if link['class']==["storylink"]:
            print(link.attrs)
#         		print(link['href'], link.text)
# Out:
# {'href': 'https://techcrunch.com/2019/08/09/biotech-researchers-venture-into-the-wild-to-start-their-own-business/', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'https://www.theguardian.com/world/2019/aug/10/russian-nuclear-agency-confirms-role-in-rocket-test-explosion', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'https://www.npr.org/2019/08/05/748207152/you-2-0-tunnel-vision', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'item?id=20664873', 'class': ['storylink']}
# {'href': 'https://irlpodcast.org/season5/episode4/', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'https://apnews.com/dea7f32d16364c6093f19b938370d600', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'https://www.quantamagazine.org/the-evolutionary-argument-against-reality-20160421/', 'class': ['storylink'], 'rel': ['nofollow']}
# {'href': 'https://en.wikipedia.org/wiki/Modular_programming', 'class': ['storylink'], 'rel': ['nofollow']}
# ...

# %%
import ast
import json

# %%
response = requests.get("https://www.easports.com/madden-nfl/player-ratings/")
soup = BeautifulSoup(response.text, "html.parser")

for link in soup.find_all():
    if 'class' in link.attrs:
        if link['class']==["ratings-hub"]:
            print(link.attrs)['ng-init'])
#             print(link['ng-init'].attrs)
# Out:
# {'class': ['ratings-hub'], 'ng-class': "{'ratings-hub--expanded': expandedView}", 'ng-controller': 'RatingsHubCtrl', 'ng-init': 'players = [{"college":"Pittsburgh","awareness_rating":99,"throwPower_rating":20,"kickReturn_rating":10,"leadBlock_rating":23,"strength_rating":99,"bCVision_rating":49,"catchInTraffic_rating":23,"playAction_rating":6,"pursuit_rating":98,"mediumRouteRunning_rating":9,"catching_rating":42,"acceleration_rating":90,"spinMove_rating":25,"height":"73","finesseMoves_rating":96,"spectacularCatch_rating":47,"runBlock_rating":45,"tackle_rating":93,"injury_rating":98,"zoneCoverage_rating":29,"weight":"280","plyrBirthdate":"5\\/23\\/91","deepRouteRunning_rating":5,"firstName":"Aaron","yearsPro":5,"totalSalary":101892000,"trucking_rating":32,"throwAccuracyShort_rating":6,"position":"RE","jukeMove_rating":28,"playRecognition_rating":99,"shortRouteRunning_rating":16,"lastName":"Donald","jerseyNum":"99","breakSack_rating":12,"speed_rating":83,"runBlockPower_rating":45,"jump
# ...

# %%
players = [{"college":"Pittsburgh","awareness_rating":99,"throwPower_rating":20,"kickReturn_rating":10,"leadBlock_rating":23,"strength_rating":99,"bCVision_rating":49,"catchInTraffic_rating":23,"playAction_rating":6,"pursuit_rating":98,"mediumRouteRunning_rating":9,"catching_rating":42,"acceleration_rating":90,"spinMove_rating":25,"height":"73","finesseMoves_rating":96,"spectacularCatch_rating":47}]

# %%
players
# Out:
# [{'college': 'Pittsburgh',
#   'awareness_rating': 99,
#   'throwPower_rating': 20,
#   'kickReturn_rating': 10,
#   'leadBlock_rating': 23,
#   'strength_rating': 99,
#   'bCVision_rating': 49,
#   'catchInTraffic_rating': 23,
#   'playAction_rating': 6,
#   'pursuit_rating': 98,
#   'mediumRouteRunning_rating': 9,
#   'catching_rating': 42,
#   'acceleration_rating': 90,
#   'spinMove_rating': 25,
#   'height': '73',
#   'finesseMoves_rating': 96,
#   'spectacularCatch_rating': 47}]

# %%
response = requests.get("https://news.ycombinator.com/newest")
soup = BeautifulSoup(response.text, "html.parser")
